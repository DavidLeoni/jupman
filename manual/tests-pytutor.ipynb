# %% [markdown]
# # Python Tutor tests
#
# There are various ways to embed Python tutor, first we put the recommended one.

# %% [markdown]
# **RECOMMENDED**: You can put a call to `jupman.pytut()` at the end of a cell, and the cell code will magically appear in python tutor in the output (except the call to `pytut()` of course).
#
# **Does not** need internet  connection.

# %%
import sys
sys.path.append('../')
import jupman

# %%
lst = [5,8,4,10,30,20,40,50,60,70,20,30]

for x in lst:
    y = x * 2
    
jupman.pytut()
# Out:
#
#         <script src="../_static/js/pytutor-embed.bundle.min.js" type="application/javascript"></script>
#
#         <style>
#         @import "../_static/css/jupman.css";
#         </style>
#
#         <script id="json-jm-86eb181480346332c72244039406f9a0-4" type="application/json" >
# ...

# %% [markdown]
# ## Scope
#
# BEWARE of variables which were initialized in previous cells, they WILL NOT be available in Python Tutor:

# %%
w = 8

# %%
x =  w + 5
jupman.pytut()
# Out:
# Traceback (most recent call last):
#   File "../jupman.py", line 2453, in _runscript
#     self.run(script_str, user_globals, user_globals)
#   File "/usr/lib/python3.7/bdb.py", line 578, in run
#     exec(cmd, globals, locals)
#   File "<string>", line 2, in <module>
# NameError: name 'w' is not defined
#
#         <script src="../_static/js/pytutor-embed.bundle.min.js" type="application/javascript"></script>
#
#         <style>
#         @import "../_static/css/jupman.css";
#         </style>
#
#         <script id="json-jm-9e3b324a5fd4bb62d93772404e88cfbc-6" type="application/json" >
#             {"code": " \nx =  w + 5", "trace": [{"line": 2, "event": "step_line", "func_name": "<module>", "globals": {}, "ordered_globals": [], "stack_to_render": [], "heap": {}, "stdout": ""}, {"line": 2, "event": "exception", "func_name": "<module>", "globals": {}, "ordered_globals": [], "stack_to_render": [], "heap": {}, "stdout": "", "exception_msg": "NameError: name 'w' is not defined"}]}
# ...

# %% [markdown]
# ## Data types
#
# Data display review:

# %%
word = "wonder"
lst = [9,7,8]
t = (6,2,4,3)
mixed_set = {3,'b','e',9, 'm', 'n'}
numbers_set = {3,4,9}
char_set = {'r','a','h'}
d = {'a' : 8,
     'b' : 4,
     'c' : 5}

empty_str = ""
empty_tuple = ()
empty_set = set()
empty_dict = {}

#import numpy  # not supported!

def f(par):
    print(par)

class C:
    def hello():
        print('ciao')
        
    def __init__(self, name, age):
        self.name = name
        self.age = age        

m = C.hello
g = f
                
c = C('blah',30)      

jupman.pytut()
# Out:
#
#         <script src="../_static/js/pytutor-embed.bundle.min.js" type="application/javascript"></script>
#
#         <style>
#         @import "../_static/css/jupman.css";
#         </style>
#
#         <script id="json-jm-236020c005455cf1250e42f61883ab8b-7" type="application/json" >
# ...

# %% [markdown]
# ## Window overflow
#
# When too much right space is taken, it might be difficult to scroll:

# %%
x = [3,2,5,2,42,34,2,4,34,2,3,4,23,4,23,4,2,34,23,4,23,4,23,4,234,34,23,4,23,4,23,4,2]

jupman.pytut()
# Out:
#
#         <script src="../_static/js/pytutor-embed.bundle.min.js" type="application/javascript"></script>
#
#         <style>
#         @import "../_static/css/jupman.css";
#         </style>
#
#         <script id="json-jm-d1041d6f3f6be6478df1e49767a12795-8" type="application/json" >
#             {"code": " \nx = [3,2,5,2,42,34,2,4,34,2,3,4,23,4,23,4,2,34,23,4,23,4,23,4,234,34,23,4,23,4,23,4,2]", "trace": [{"line": 2, "event": "step_line", "func_name": "<module>", "globals": {}, "ordered_globals": [], "stack_to_render": [], "heap": {}, "stdout": ""}, {"line": 2, "event": "return", "func_name": "<module>", "globals": {"x": ["REF", 1]}, "ordered_globals": ["x"], "stack_to_render": [], "heap": {"1": ["LIST", 3, 2, 5, 2, 42, 34, 2, 4, 34, 2, 3, 4, 23, 4, 23, 4, 2, 34, 23, 4, 23, 4, 23, 4, 234, 34, 23, 4, 23, 4, 23, 4, 2]}, "stdout": ""}]}
#         </script>
#         <div id="jm-d1041d6f3f6be6478df1e49767a12795-8" class="pytutorVisualizer"> </div>
#
#         <script>
#
# ...

# %% [markdown]
# ## pytut execution
#
#
# Some cells might execute in Jupyter but not so well in Python Tutor, due to [its inherent limitations](https://github.com/pgbovine/OnlinePythonTutor/blob/master/unsupported-features.md):

# %%
x = 0
for i in range(10000):
    x += 1
print(x)
jupman.pytut()
# Out:
# 10000
#
#         <script src="../_static/js/pytutor-embed.bundle.min.js" type="application/javascript"></script>
#
#         <style>
#         @import "../_static/css/jupman.css";
#         </style>
#
#         <script id="json-jm-55aa8dd1c6c0fdbad4653303ee4ca922-9" type="application/json" >
# ...

# %% [markdown]
# ## Infinite loops
#
# Since execution occurs first in Jupyter and then in Python tutor, if you have an infinite loop no Python Tutor instance will be spawned:
#
# ```python
# while True:
#     pass
#
# jupman.pytut()
# ```

# %% [markdown]
# ## Resizability
#
# Long vertical and horizontal expansion should work:

# %%
x = {0:'a'}
for i in range(1,30):
    x[i] = x[i-1]+str(i*10000)
jupman.pytut()
# Out:
#
#         <script src="../_static/js/pytutor-embed.bundle.min.js" type="application/javascript"></script>
#
#         <style>
#         @import "../_static/css/jupman.css";
#         </style>
#
#         <script id="json-jm-96480223e88e12699e2bc38b466a2788-10" type="application/json" >
# ...

# %% [markdown]
# ## Cross arrows
#
# With multiple visualizations, arrows shouldn't cross from one to the other even if underlying script is loaded multiple times (relates to visualizerIdOverride)

# %%
x = [1,2,3]


jupman.pytut()
# Out:
#
#         <script src="../_static/js/pytutor-embed.bundle.min.js" type="application/javascript"></script>
#
#         <style>
#         @import "../_static/css/jupman.css";
#         </style>
#
#         <script id="json-jm-d69c26ac1624e6b5ec2ccaa4b7e34c7f-11" type="application/json" >
#             {"code": " \nx = [1,2,3]", "trace": [{"line": 2, "event": "step_line", "func_name": "<module>", "globals": {}, "ordered_globals": [], "stack_to_render": [], "heap": {}, "stdout": ""}, {"line": 2, "event": "return", "func_name": "<module>", "globals": {"x": ["REF", 1]}, "ordered_globals": ["x"], "stack_to_render": [], "heap": {"1": ["LIST", 1, 2, 3]}, "stdout": ""}]}
#         </script>
#         <div id="jm-d69c26ac1624e6b5ec2ccaa4b7e34c7f-11" class="pytutorVisualizer"> </div>
#
#         <script>
#
#         (function(){
#             console.log("jupman.py embedded javascript: adding Python tutor visualizer...")
#
# ...

# %% [markdown]
# ## Print output - no lines

# %%
y = [1,2,3,4]


jupman.pytut()
# Out:
#
#         <script src="../_static/js/pytutor-embed.bundle.min.js" type="application/javascript"></script>
#
#         <style>
#         @import "../_static/css/jupman.css";
#         </style>
#
#         <script id="json-jm-14d64cfd043fd0a01305d91cd37edceb-12" type="application/json" >
#             {"code": " \ny = [1,2,3,4]", "trace": [{"line": 2, "event": "step_line", "func_name": "<module>", "globals": {}, "ordered_globals": [], "stack_to_render": [], "heap": {}, "stdout": ""}, {"line": 2, "event": "return", "func_name": "<module>", "globals": {"y": ["REF", 1]}, "ordered_globals": ["y"], "stack_to_render": [], "heap": {"1": ["LIST", 1, 2, 3, 4]}, "stdout": ""}]}
#         </script>
#         <div id="jm-14d64cfd043fd0a01305d91cd37edceb-12" class="pytutorVisualizer"> </div>
#
#         <script>
#
#         (function(){
#             console.log("jupman.py embedded javascript: adding Python tutor visualizer...")
#
# ...

# %% [markdown]
# ## Print output - one line
#
# With only one line of print, Print output panel shouldn't be too short:

# %%
print("hello")

jupman.pytut()
# Out:
# hello
#
#         <script src="../_static/js/pytutor-embed.bundle.min.js" type="application/javascript"></script>
#
#         <style>
#         @import "../_static/css/jupman.css";
#         </style>
#
#         <script id="json-jm-c4db48ce1265b9a07eaf2bd9bfd7a869-13" type="application/json" >
#             {"code": " \nprint(\"hello\")", "trace": [{"line": 2, "event": "step_line", "func_name": "<module>", "globals": {}, "ordered_globals": [], "stack_to_render": [], "heap": {}, "stdout": ""}, {"line": 2, "event": "return", "func_name": "<module>", "globals": {}, "ordered_globals": [], "stack_to_render": [], "heap": {}, "stdout": "hello\n"}]}
#         </script>
#         <div id="jm-c4db48ce1265b9a07eaf2bd9bfd7a869-13" class="pytutorVisualizer"> </div>
#
#         <script>
#
#         (function(){
#             console.log("jupman.py embedded javascript: adding Python tutor visualizer...")
#
# ...

# %% [markdown]
# ## Print output - 5 lines
#
# With many printed lines, print output should resize accordingly. Currently it doesn't, see [#116](https://github.com/DavidLeoni/jupman/issues/116).

# %%
print("zappa")
print("peppa")
print("gnappa")
print("lompa")
print("gnompa")

jupman.pytut()
# Out:
# zappa
# peppa
# gnappa
# lompa
# gnompa
#
#         <script src="../_static/js/pytutor-embed.bundle.min.js" type="application/javascript"></script>
#
#         <style>
#         @import "../_static/css/jupman.css";
#         </style>
#
#         <script id="json-jm-6d57f57240d8a5ce75e18a3c3eedcb3f-14" type="application/json" >
# ...

# %% [markdown]
# ## Print output - mid-sized line
#
# When printing a mid-sized line, print output should enlarge accordingly. Currently it doesn't.

# %%
print("pappa" * 10)

jupman.pytut()
# Out:
# pappapappapappapappapappapappapappapappapappapappa
#
#         <script src="../_static/js/pytutor-embed.bundle.min.js" type="application/javascript"></script>
#
#         <style>
#         @import "../_static/css/jupman.css";
#         </style>
#
#         <script id="json-jm-2e7c14f6981d39cc6e24dbfa9eb82d20-15" type="application/json" >
#             {"code": " \nprint(\"pappa\" * 10)", "trace": [{"line": 2, "event": "step_line", "func_name": "<module>", "globals": {}, "ordered_globals": [], "stack_to_render": [], "heap": {}, "stdout": ""}, {"line": 2, "event": "return", "func_name": "<module>", "globals": {}, "ordered_globals": [], "stack_to_render": [], "heap": {}, "stdout": "pappapappapappapappapappapappapappapappapappapappa\n"}]}
#         </script>
#         <div id="jm-2e7c14f6981d39cc6e24dbfa9eb82d20-15" class="pytutorVisualizer"> </div>
#
#         <script>
#
#         (function(){
#             console.log("jupman.py embedded javascript: adding Python tutor visualizer...")
# ...

# %% [markdown]
# ## Print output - extra-long line
#
# When printing a very long line, a scrollbar should appear

# %%
print("zappa" * 30)

jupman.pytut()
# Out:
# zappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappa
#
#         <script src="../_static/js/pytutor-embed.bundle.min.js" type="application/javascript"></script>
#
#         <style>
#         @import "../_static/css/jupman.css";
#         </style>
#
#         <script id="json-jm-b1d987c242cef7fbd9ade5d99b003fab-16" type="application/json" >
#             {"code": " \nprint(\"zappa\" * 30)", "trace": [{"line": 2, "event": "step_line", "func_name": "<module>", "globals": {}, "ordered_globals": [], "stack_to_render": [], "heap": {}, "stdout": ""}, {"line": 2, "event": "return", "func_name": "<module>", "globals": {}, "ordered_globals": [], "stack_to_render": [], "heap": {}, "stdout": "zappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappazappa\n"}]}
#         </script>
# ...

# %% [markdown]
# ## Alignment test 1
#
# Test for [#105](https://github.com/DavidLeoni/jupman/issues/105): before fixing red arrow was badly misaligned and went way past the function call.

# %%
def f(mat, i):
    """  Do something"""

    row = []
    row.append(mat[i ])
    return row

f([[2,3,4]], 0)
jupman.pytut()
# Out:
#
#         <script src="../_static/js/pytutor-embed.bundle.min.js" type="application/javascript"></script>
#
#         <style>
#         @import "../_static/css/jupman.css";
#         </style>
#
#         <script id="json-jm-3912771b529650087106ed455c4bcc95-17" type="application/json" >
# ...

# %% [markdown]
# ## Alignment test 2
#
# Check the arrow stays on right line even in long code.

# %%
def f(mat, i):
    """  Do something else"""

    row = []
    row.append(mat[i])
    return row

m = [
      ['a','b'],
      ['c','d'],
      ['a','e'],
]

#row = f(m,0)

x = 3
if x == x:
    m = [
        [1,2,3],
        [4,3]
    ]
print("zim")

y = 1
if y == y:
    m = [
        [1,2,3],
        [4,3]
    ]
print("zam")

    
jupman.pytut()
# Out:
# zim
# zam
#
#         <script src="../_static/js/pytutor-embed.bundle.min.js" type="application/javascript"></script>
#
#         <style>
#         @import "../_static/css/jupman.css";
#         </style>
#
#         <script id="json-jm-21d38f567136cbbd9a2b4851a963dae4-18" type="application/json" >
# ...

# %% [markdown]
# ## Cloned cell test
#
# Tests PythonTutor output is correctly displayed when cells are cloned ([solved issue](https://github.com/DavidLeoni/jupman/issues/126))

# %%
maremma = 123
jupman.pytut()
# Out:
#
#         <script src="../_static/js/pytutor-embed.bundle.min.js" type="application/javascript"></script>
#
#         <style>
#         @import "../_static/css/jupman.css";
#         </style>
#
#         <script id="json-jm-b6f2c76287cc0374def07a0f8ae7f517-19" type="application/json" >
#             {"code": " \nmaremma = 123", "trace": [{"line": 2, "event": "step_line", "func_name": "<module>", "globals": {}, "ordered_globals": [], "stack_to_render": [], "heap": {}, "stdout": ""}, {"line": 2, "event": "return", "func_name": "<module>", "globals": {"maremma": 123}, "ordered_globals": ["maremma"], "stack_to_render": [], "heap": {}, "stdout": ""}]}
#         </script>
#         <div id="jm-b6f2c76287cc0374def07a0f8ae7f517-19" class="pytutorVisualizer"> </div>
#
#         <script>
#
#         (function(){
#             console.log("jupman.py embedded javascript: adding Python tutor visualizer...")
#
# ...

# %% [markdown]
# Cloned cell:

# %%
maremma = 123
jupman.pytut()
# Out:
#
#         <script src="../_static/js/pytutor-embed.bundle.min.js" type="application/javascript"></script>
#
#         <style>
#         @import "../_static/css/jupman.css";
#         </style>
#
#         <script id="json-jm-b6f2c76287cc0374def07a0f8ae7f517-20" type="application/json" >
#             {"code": " \nmaremma = 123", "trace": [{"line": 2, "event": "step_line", "func_name": "<module>", "globals": {}, "ordered_globals": [], "stack_to_render": [], "heap": {}, "stdout": ""}, {"line": 2, "event": "return", "func_name": "<module>", "globals": {"maremma": 123}, "ordered_globals": ["maremma"], "stack_to_render": [], "heap": {}, "stdout": ""}]}
#         </script>
#         <div id="jm-b6f2c76287cc0374def07a0f8ae7f517-20" class="pytutorVisualizer"> </div>
#
#         <script>
#
#         (function(){
#             console.log("jupman.py embedded javascript: adding Python tutor visualizer...")
#
# ...

# %% [markdown]
# ## Nested data structures
#
# Data structures shouldn't be displayed as nested (which is the actual default on Python Tutor site). Test for [this issue](https://github.com/DavidLeoni/jupman/issues/132)

# %%
listA = [ ['Keep', 'an'], 
          ['eye', 'on'],
          ['the', 'arrow', 'tips']
]

listB = listA.copy()
jupman.pytut()
# Out:
#
#         <script src="../_static/js/pytutor-embed.bundle.min.js" type="application/javascript"></script>
#
#         <style>
#         @import "../_static/css/jupman.css";
#         </style>
#
#         <script id="json-jm-79f3b21de5179bcdf20e985ef3cc5b11-21" type="application/json" >
# ...

# %%
sa = "ciao"
sb = sa



listonaA = [ ['Fate', 'attenzione'], 
             ['a', 'dove'],
             ['puntano', 'le', 'frecce']
]

listonaB = listonaA.copy()
jupman.pytut()
# Out:
#
#         <script src="../_static/js/pytutor-embed.bundle.min.js" type="application/javascript"></script>
#
#         <style>
#         @import "../_static/css/jupman.css";
#         </style>
#
#         <script id="json-jm-20f13185e90d7f176e605ed1b4deb8ad-22" type="application/json" >
# ...

# %% [markdown]
# ## Function pointers
#
# Containers should always contain links to functions, not inlined names

# %%
def f():
    print('hello')

def g():
    print('world')

fs = [f,g]

jupman.pytut()
# Out:
#
#         <script src="../_static/js/pytutor-embed.bundle.min.js" type="application/javascript"></script>
#
#         <style>
#         @import "../_static/css/jupman.css";
#         </style>
#
#         <script id="json-jm-fe49032ba88dadf5dec22b7537642670-23" type="application/json" >
# ...

# %%
listonaA = [ ['Fate', 'attenzione'], 
             ['a', 'dove'],
             ['puntano', 'le', 'frecce']
]

listonaB = listonaA.copy()
jupman.pytut()
# Out:
#
#         <script src="../_static/js/pytutor-embed.bundle.min.js" type="application/javascript"></script>
#
#         <style>
#         @import "../_static/css/jupman.css";
#         </style>
#
#         <script id="json-jm-bac7c148311e2652d7b7bbc615fee4c3-24" type="application/json" >
# ...

# %% [markdown]
# ## Alternative: HTML magics
#
# Another option is to directly paste Python Tutor iframe in the cells, and use Jupyter `%%HTML` magics command.
#
# HTML should be available both in notebook and website - of course, requires an internet connection.
#
# Beware: you need the HTTP**S** !

# %%
# %%HTML
#
# <iframe width="800" height="300" frameborder="0"
#         src="https://pythontutor.com/iframe-embed.html#code=x+%3D+5%0Ay+%3D+10%0Az+%3D+x+%2B+y&cumulative=false&py=3&curInstr=3">
# </iframe>
# Out:
# <iframe width="800" height="300" frameborder="0"
#         src="https://pythontutor.com/iframe-embed.html#code=x+%3D+5%0Ay+%3D+10%0Az+%3D+x+%2B+y&cumulative=false&py=3&curInstr=3">
# </iframe>

# %% [markdown]
# ## Alternative: NBTutor

# %% [markdown]
# To show Python Tutor in notebooks, there is already a jupyter extension called [NBTutor](https://github.com/lgpage/nbtutor) , afterwards you can use magic `%%nbtutor` to show the interpreter.
#
# Unfortunately, it doesn't show in the generated HTML :-/

# %%
# %reload_ext nbtutor

# %%
# %%nbtutor
#
# for x in range(1,4):
#     print("ciao")
# x=5
# y=7
# x +y
# Out:
# ciao
# ciao
# ciao
# 12
